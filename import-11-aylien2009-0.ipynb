# %%
import time
import pandas as pd
import numpy as np
from aylienapiclient import textapi

tweetDF0 = pd.read_csv('analysis-5.csv')
#tweetDF0.iloc[290:296, 4:6]                 # counting! shows six rows up to row 295 and two columns up to column five
tweetDF0.iloc[0:292, 5:6]                    # so this is what I pass to Aylien


#time.sleep(12) 

#tweetEUParly = tweetDF0.loc["2009-06-03":"2009-06-05","Lang":"Tweets"]
#tweetEUParly.iloc[:6]

#'''
#This works.  Limit of 1,000 tweets total
#aylienClient = textapi.Client("2e3652f1", "77e0e2e019d20ea8aba8ad12572507a7")
#aylienSentiment = aylienClient.Sentiment({"text": "- wert' Always been/ @labour but can't help but respect @David_Cameron putting his neck on the line for #Remain while @jeremycorbyn took back seat"})
#print(aylienSentiment)
#
#{'polarity': 'negative', 'subjectivity': 'objective', 'text': "- wert' Always been/ @labour but can't help but respect @David_Cameron putting his neck on the line for #Remain while @jeremycorbyn took back seat", 'polarity_confidence': 0.5615213513374329, 'subjectivity_confidence': 0.9998733011656746}
#'''
# Out:
#                                                 Tweets
# 0    ''Ist die EU-Wahl ein erster Indikator f\\xfcr...
# 1    ''Ist die EU-Wahl ein erster Indikator f\\xfcr...
# 2    '@agnostic900rr unentschlossen bin ich auch, a...
# 3           '@burkardt Gut zu wissen! #de #eu #domain'
# 4     '@burkardt Sehr gutes Feature! #eu #de #domains'
# 5    '@Danielsaint #eu #escrevo #tudo #em #tags #t\...
# 6    '@ehkloa: als 'wahlverlierer' seh ich mich jet...
# 7    '@Goddersukip #UKIP? Real change? You mean sex...
# 8    '@HeikoKunert Laut #RNIB gibt es Wahlschablone...
# 9    '@IanSkerrett pity it harms open source so muc...
# 10   '@JamesMoyies  Do you think we could make it i...
# 11   '@juryteam dishonesty about #ukip - http://bit...
# 12   '@kaktusmann wir erwarten von der #CSU- nichts...
# 13   '@Leave_EU - Idiots. UKIP will poll 20% tomorr...
# 14   '@Matov #UKIP are proud to have black and Asia...
# 15   '@mattymax Do some proper research: #UKIP has ...
# 16   '@Moonchild66 All policies are published on we...
# 17   '@Moonchild66 It is an EU election tomorrow. W...
# 18                   '@Nigel2009  #UKIP  Got my vote!'
# 19   '@Nigel2009 Good luck on pushing the #UKIP mes...
# 20   '@Nigel2009 That reminds me... I have the last...
# 21   '@spdLohmar2009: Werden die meisten interessie...
# 22   '@steve2425 Well done. I was lucky as there we...
# 23   '@syedjafri follow-up to talk by Dr Peter Piot...
# 24   '@ThisStarChild Its a clear choice. Stay in EU...
# 25   '@wahlschlepper 1. manchmal gibt es Kekse (bei...
# 26   '@wahlschlepper 2. Wer die Welt nicht mitgesta...
# 27   '@wahlschlepper 3. Man kann das W\\xe4hlen pri...
# 28   '@wahlschlepper 4. ...und ein paar nette Leute...
# 29   '@wahlschlepper Weil man immer versuchen sollt...
# ..                                                 ...
# 262  'still writing...but slowly getting ready to w...
# 263  'SZ in aller K\\xfcrze: Friedrich Merz \\xfcbe...
# 264  'Taugt die Europawahl als Orakel? http://tinyu...
# 265  'taz-Interview: 'Wir zeigen ihnen das wahre Eu...
# 266  'Thank you to everyone who put up with my \\xa...
# 267  'The behemoth, antidemocratic #EU- is a fuckin...
# 268  'The people I met yesterday were not protestin...
# 269  'The vetoed pictures by Berlusconi...freedom o...
# 270  'This #EU #election seems 2B the triumph for t...
# 271  'UK Local elections results map http://tinyurl...
# 272  'Und - geht ihr am Sonntag zur Europa-Wahl? ht...
# 273  'W\\xfcrfeln gegen Strache! - Wie man am Sonnt...
# 274  'wahlaufruf von dr. alois mock  http://bit.ly/...
# 275  'war heute am Canvassing-Stand der @CDULilient...
# 276  'Warum unbedingt jeder zur Europawahl gehen mu...
# 277  'wer will die @wahlschlepper im tv sehen? heut...
# 278  @gellyfish that's what you get when you have a...
# 279  #EU 09 Comme tous ceux qui l'ont fait, j'ai en...
# 280                #EU Jag har r\\xf6stat / I've voted
# 281  #UKIP 2nd place in five divisions in #Runnymed...
# 282  A great result in the local elections for #UKI...
# 283  Am Sonntag sind #EU-Wahlen! Nicht vergessen in...
# 284  Complained to Greenwich's electoral office abo...
# 285  D66 & GroenLinks halen allebei zo'n 20 procent...
# 286  Eric Pickles says Conservatives have a secret ...
# 287  EU Patent Office refuses spanish amicus brief ...
# 288  I'm really wondering what the results of this ...
# 289  It says a lot about your party if your support...
# 290  Lady Macbeth's ambition fulfilled: Glynnis Kin...
# 291  Morning after elections, and what's on Metro's...
#
# [292 rows x 1 columns]
