# %%
import pandas as pd
import numpy as np
from aylienapiclient import textapi

tweetDF0 = pd.read_csv('analysis-5.csv')
#tweetDF0.iloc[-6:]                         # check all 27017 (including row zero) rows are there
tweetDF0.iloc[:6]                         # check first six rows (including row zero)
# Out:
#   TweetDay   TweetDate TweetTime  TweetMoon Lang  \
# 0      Wed  2009-06-03  07:44:13       0.79   de
# 1      Wed  2009-06-03  07:44:13       0.79   en
# 2      Wed  2009-06-03  17:00:09       0.79   de
# 3      Wed  2009-06-03  14:44:46       0.79   en
# 4      Wed  2009-06-03  16:13:14       0.79   en
# 5      Wed  2009-06-03  20:26:25       0.79   en
#
#                                               Tweets  aylienPolarity  \
# 0  ''Ist die EU-Wahl ein erster Indikator f\\xfcr...             NaN
# 1  ''Ist die EU-Wahl ein erster Indikator f\\xfcr...             NaN
# 2  '@agnostic900rr unentschlossen bin ich auch, a...             NaN
# 3         '@burkardt Gut zu wissen! #de #eu #domain'             NaN
# 4   '@burkardt Sehr gutes Feature! #eu #de #domains'             NaN
# 5  '@Danielsaint #eu #escrevo #tudo #em #tags #t\...             NaN
#
#    aylienSubjectivity  SentimentB              Location FollowersCount  \
# ...
